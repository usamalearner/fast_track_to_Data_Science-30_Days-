# %% [markdown]
# Day 2 of data Science fast Track learn some concepts about probability

# %%
a = 'banana'

b = 'cherry'

fruits = ['apple' , 'mango' , a , b]
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'cherry']

# %%
#List
vowel = ['a' , 'e' , 'i']
print(vowel)
# Out:
# ['a', 'e', 'i']

# %%
family = ['ali' , 10 , 'bisma' , 15 , 'ahmed' , '40' , 'sara' , 36, True, 2.5]
print(family)
# Out:
# ['ali', 10, 'bisma', 15, 'ahmed', '40', 'sara', 36, True, 2.5]

# %%
child2 = 10
child1 = 15
father = 40
mother = 36
#List of lists
complete_family = [ ['ali',child1, True] , ['bisma',child2] , ['ahmed',father] , ['sara',mother]]
print(complete_family)
# Out:
# [['ali', 15, True], ['bisma', 10], ['ahmed', 40], ['sara', 36]]

# %%
#access items from a list
family[3]
# Out:
# 15

# %%
family[-2]
# Out:
# True

# %%
family[1] + family[3]
# Out:
# 25

# %%
family[0:4]
# Out:
# ['ali', 10, 'bisma', 15]

# %%
complete_family[0]
# Out:
# ['ali', 15, True]

# %%
complete_family[0:2]
# Out:
# [['ali', 15, True], ['bisma', 10]]

# %%
family_again = ['ali' , 10 , 'bisma' , 15 , 'ahmed' , '40' , 'sara' , 36]

# %%
#over_write
family_again[1] = 12

# %%
family_again
# Out:
# ['ali', 12, 'bisma', 15, 'ahmed', '40', 'sara', 36]

# %%
family_again[0] = 'ammar'

# %%
family_again
# Out:
# ['ammar', 12, 'bisma', 15, 'ahmed', '40', 'sara', 36]

# %%
family
# Out:
# ['ali', 10, 'bisma', 15, 'ahmed', '40', 'sara', 36, True, 2.5]

# %%
#concatenation
family = family + ['tanveer' , 60 , 'zehra' , 52]

# %%
family
# Out:
# ['ali',
#  10,
#  'bisma',
#  15,
#  'ahmed',
#  '40',
#  'sara',
#  36,
#  True,
#  2.5,
#  'tanveer',
#  60,
#  'zehra',
#  52,
#  'tanveer',
#  60,
#  'zehra',
#  52]

# %%
del(family[0:4])

# %%
family
# Out:
# ['ahmed',
#  '40',
#  'sara',
#  36,
#  True,
#  2.5,
#  'tanveer',
#  60,
#  'zehra',
#  52,
#  'tanveer',
#  60,
#  'zehra',
#  52]
